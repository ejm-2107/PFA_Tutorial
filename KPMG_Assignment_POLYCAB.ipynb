# %% [markdown]
# **Importing the required Libraries**

# %%
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# **DATES**

# %%
start = dt.date(2015,7,29)
end = dt.date(2022,3,31)

# %%
end-start
# Out:
# datetime.timedelta(days=2437)

# %%
X=2437/365
X
# Out:
# 6.676712328767123

# %% [markdown]
# **Downloading data for POLYCAB**

# %%
poly = yf.download('POLYCAB.NS',start,end)
poly
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-04-16   633.000000   667.799988   630.000000   654.799988   635.661316
# 2019-04-18   656.900024   664.900024   614.000000   643.549988   624.740051
# 2019-04-22   643.000000   645.799988   625.250000   628.099976   609.741638
# 2019-04-23   628.000000   648.000000   628.000000   634.099976   615.566284
# 2019-04-24   636.500000   640.000000   628.250000   637.500000   618.866882
# ...                 ...          ...          ...          ...          ...
# 2022-03-24  2400.000000  2439.800049  2395.199951  2405.600098  2375.919922
# 2022-03-25  2409.399902  2498.000000  2409.399902  2446.899902  2416.710205
# 2022-03-28  2454.000000  2459.800049  2342.000000  2352.149902  2323.129150
# 2022-03-29  2357.500000  2394.899902  2336.250000  2350.800049  2321.795898
# ...

# %% [markdown]
# **The First 3 Values**

# %%
poly.head(3)
# Out:
#                   Open        High     Low       Close   Adj Close    Volume
# Date
# 2019-04-16  633.000000  667.799988  630.00  654.799988  635.661316  22985293
# 2019-04-18  656.900024  664.900024  614.00  643.549988  624.740051   5415019
# 2019-04-22  643.000000  645.799988  625.25  628.099976  609.741638   1059760

# %% [markdown]
# **The Last 3 Values**

# %%
poly.tail(3)
# Out:
#               Open         High          Low        Close    Adj Close  Volume
# Date
# 2022-03-28  2454.0  2459.800049  2342.000000  2352.149902  2323.129150  303521
# 2022-03-29  2357.5  2394.899902  2336.250000  2350.800049  2321.795898  238300
# 2022-03-30  2380.0  2390.000000  2352.199951  2362.350098  2333.203613  182382

# %% [markdown]
# **ANALYSIS**

# %%
poly['Close'].mean()
# Out:
# 1293.6111484428436

# %%
poly['Open'].mean()
# Out:
# 1294.5056078032821

# %%
poly['Close'].plot(figsize=(10,4))
# Out:
# <Axes: xlabel='Date'>

# %%
adj_d = poly['Adj Close']
adj_d
# Out:
# Date
# 2019-04-16     635.661316
# 2019-04-18     624.740051
# 2019-04-22     609.741638
# 2019-04-23     615.566284
# 2019-04-24     618.866882
#                  ...
# 2022-03-24    2375.919922
# 2022-03-25    2416.710205
# 2022-03-28    2323.129150
# 2022-03-29    2321.795898
# 2022-03-30    2333.203613
# Name: Adj Close, Length: 731, dtype: float64

# %%
df_100 = adj_d/adj_d.iloc[0]*100
df_100
# Out:
# Date
# 2019-04-16    100.000000
# 2019-04-18     98.281905
# 2019-04-22     95.922408
# 2019-04-23     96.838720
# 2019-04-24     97.357959
#                  ...
# 2022-03-24    373.771356
# 2022-03-25    380.188340
# 2022-03-28    365.466498
# 2022-03-29    365.256755
# 2022-03-30    367.051377
# Name: Adj Close, Length: 731, dtype: float64

# %%
T_return = adj_d/adj_d.shift(1)-1
T_return
# Out:
# Date
# 2019-04-16         NaN
# 2019-04-18   -0.017181
# 2019-04-22   -0.024007
# 2019-04-23    0.009553
# 2019-04-24    0.005362
#                 ...
# 2022-03-24   -0.003480
# 2022-03-25    0.017168
# 2022-03-28   -0.038722
# 2022-03-29   -0.000574
# 2022-03-30    0.004913
# Name: Adj Close, Length: 731, dtype: float64

# %%
T_return.plot(figsize=(10,4))
# Out:
# <Axes: xlabel='Date'>

# %%
T_return.mean()*1000*X
# Out:
# 13.88390696322801
